# %%
# Load libraries
import pinecone
from tqdm.autonotebook import tqdm
import openai
import pandas as pd
import numpy as np
import re
import os
from transformers import pipeline
import textwrap
import warnings
warnings.filterwarnings('ignore')

# %%
# Read your OpenAI and Pinecone keys from the environment
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY') 
PINECONE_API_KEY = os.getenv('PINECONE_API_KEY')
PINECONE_ENV = os.getenv('PINECONE_API_ENV')

# %%
# this code is generated by the Domino Code Assist toolbar button
import domino_code_assist as dca
dca.init()
# Out:
# Cannot show ipywidgets in text

# %%
# initialize pinecone
pinecone.init(
    api_key=PINECONE_API_KEY,
    environment=PINECONE_ENV
)

index_name = "medical-qa-search"
index = pinecone.Index(index_name)

# %%
# Read the medical diagnostic data into a dataframe

df = pd.read_csv("/mnt/code/data/disease_components.csv")
df.head()
# Out:
#                       name                                               link  \
# 0     Acanthosis nigricans  https://www.mayoclinic.org/diseases-conditions...
# 1                Achalasia  https://www.mayoclinic.org/diseases-conditions...
# 2  Achilles tendon rupture  https://www.mayoclinic.org/diseases-conditions...
# 3  Acute coronary syndrome  https://www.mayoclinic.org/diseases-conditions...
# 4              Adenomyosis  https://www.mayoclinic.org/diseases-conditions...
#
#                                             Symptoms  \
# 0  ["Skin changes are the only signs of acanthosi...
# 1  ['Achalasia symptoms generally appear graduall...
# 2  ["Although it's possible to have no signs or s...
# 3  ['The signs and symptoms of acute coronary syn...
# 4  ['Sometimes, adenomyosis causes no signs or sy...
#
#                                             Overview  \
# 0  ['', 'Acanthosis nigricans is a skin condition...
# 1  ['Achalasia is a rare disorder that makes it d...
# 2  ['', 'The Achilles tendon is a strong fibrous ...
# 3  ['Acute coronary syndrome is a term used to de...
# 4  ['', 'With adenomyosis, the same tissue that l...
#
#                                               Causes  \
# 0  ['Acanthosis nigricans has been associated wit...
# 1  ['The exact cause of achalasia is poorly under...
# 2  ['Your Achilles tendon helps you point your fo...
# 3  ['Acute coronary syndrome usually results from...
# 4  ["The cause of adenomyosis isn't known. There ...
#
#                                         Risk factors  \
# 0  ['Acanthosis nigricans risk factors include:',...
# 1                                                NaN
# 2  ['Factors that may increase your risk of Achil...
# 3  ['The risk factors for acute coronary syndrome...
# 4  ['Risk factors for adenomyosis include:', 'Mos...
#
#                                            diagnosis
# 0  ['Acanthosis nigricans is typically detected d...
# 1  ['Achalasia can be overlooked or misdiagnosed ...
# 2  ['During the physical exam, your doctor will i...
# 3  ['If you have signs or symptoms associated wit...
# 4  ['Some other uterine conditions can cause sign...

# %%
find = ["\[","\]","\'","\"","\,"]
replace = ['','','','','']

df = df.replace(find, replace, regex=True)
df.head()
# Out:
#                       name                                               link  \
# 0     Acanthosis nigricans  https://www.mayoclinic.org/diseases-conditions...
# 1                Achalasia  https://www.mayoclinic.org/diseases-conditions...
# 2  Achilles tendon rupture  https://www.mayoclinic.org/diseases-conditions...
# 3  Acute coronary syndrome  https://www.mayoclinic.org/diseases-conditions...
# 4              Adenomyosis  https://www.mayoclinic.org/diseases-conditions...
#
#                                             Symptoms  \
# 0  Skin changes are the only signs of acanthosis ...
# 1  Achalasia symptoms generally appear gradually ...
# 2  Although its possible to have no signs or symp...
# 3  The signs and symptoms of acute coronary syndr...
# 4  Sometimes adenomyosis causes no signs or sympt...
#
#                                             Overview  \
# 0   Acanthosis nigricans is a skin condition that...
# 1  Achalasia is a rare disorder that makes it dif...
# 2   The Achilles tendon is a strong fibrous cord ...
# 3  Acute coronary syndrome is a term used to desc...
# 4   With adenomyosis the same tissue that lines t...
#
#                                               Causes  \
# 0  Acanthosis nigricans has been associated with:...
# 1  The exact cause of achalasia is poorly underst...
# 2  Your Achilles tendon helps you point your foot...
# 3  Acute coronary syndrome usually results from t...
# 4  The cause of adenomyosis isnt known. There hav...
#
#                                         Risk factors  \
# 0  Acanthosis nigricans risk factors include:    ...
# 1                                                NaN
# 2  Factors that may increase your risk of Achille...
# 3  The risk factors for acute coronary syndrome a...
# 4  Risk factors for adenomyosis include: Most cas...
#
#                                            diagnosis
# 0  Acanthosis nigricans is typically detected dur...
# 1  Achalasia can be overlooked or misdiagnosed be...
# 2  During the physical exam your doctor will insp...
# 3  If you have signs or symptoms associated with ...
# 4  Some other uterine conditions can cause signs ...

# %%
# Data tansformation with DCA - removing NaN values from data
df_sym = df.loc[df["Symptoms"].notna()]
df_ovr = df_sym.loc[df_sym["Overview"].notna()]
df_causes = df_ovr.loc[df_ovr["Causes"].notna()]
df_rf = df_causes.loc[df_causes["Risk factors"].notna()]
df_ppNaN = df_rf.loc[df_rf["diagnosis"].notna()]
df_ppNaN
# Out:
#                                                    name  \
# 0                                  Acanthosis nigricans
# 2                               Achilles tendon rupture
# 3                               Acute coronary syndrome
# 4                                           Adenomyosis
# 5                                  Adjustment disorders
# ...                                                 ...
# 1176                                       Yellow fever
# 1177  Yersinia pestis (See: Yersinia pestis, also kn...
# 1179                                         Zika virus
# 1180                         Zollinger-Ellison syndrome
# 1181        Zoster (See: Zoster, also known asShingles)
#
#                                                    link  \
# 0     https://www.mayoclinic.org/diseases-conditions...
# 2     https://www.mayoclinic.org/diseases-conditions...
# 3     https://www.mayoclinic.org/diseases-conditions...
# 4     https://www.mayoclinic.org/diseases-conditions...
# 5     https://www.mayoclinic.org/diseases-conditions...
# ...                                                 ...
# 1176  https://www.mayoclinic.org/diseases-conditions...
# 1177  https://www.mayoclinic.org/diseases-conditions...
# 1179  https://www.mayoclinic.org/diseases-conditions...
# 1180  https://www.mayoclinic.org/diseases-conditions...
# 1181  https://www.mayoclinic.org/diseases-conditions...
#
#                                                Symptoms  \
# 0     ["Skin changes are the only signs of acanthosi...
# 2     ["Although it's possible to have no signs or s...
# 3     ['The signs and symptoms of acute coronary syn...
# 4     ['Sometimes, adenomyosis causes no signs or sy...
# 5     ['Signs and symptoms depend on the type of adj...
# ...                                                 ...
# 1176  ["During the first three to six days after you...
# 1177  ['Plague is divided into three main types — bu...
# 1179  ['As many as 4 out of 5 people infected with t...
# 1180  ['Signs and symptoms of Zollinger-Ellison synd...
# 1181  ['', 'Shingles is characterized by pain or a t...
#
#                                                Overview  \
# 0     ['', 'Acanthosis nigricans is a skin condition...
# 2     ['', 'The Achilles tendon is a strong fibrous ...
# 3     ['Acute coronary syndrome is a term used to de...
# 4     ['', 'With adenomyosis, the same tissue that l...
# 5     ['Adjustment disorders are stress-related cond...
# ...                                                 ...
# 1176  ['Yellow fever is a viral infection spread by ...
# 1177  ["Plague is a serious bacterial infection that...
# 1179  ['The mosquito that carries the Zika virus is ...
# 1180  ['Zollinger-Ellison syndrome is a rare conditi...
# 1181  ['Shingles is a viral infection that causes a ...
#
#                                                  Causes  \
# 0     ['Acanthosis nigricans has been associated wit...
# 2     ['Your Achilles tendon helps you point your fo...
# 3     ['Acute coronary syndrome usually results from...
# 4     ["The cause of adenomyosis isn't known. There ...
# 5     ['Adjustment disorders are caused by significa...
# ...                                                 ...
# 1176  ['Yellow fever is caused by a virus that is sp...
# 1177  ['The plague bacteria, Yersinia pestis, is tra...
# 1179  ['The Zika virus is transmitted primarily thro...
# 1180  ['', 'The pancreas is a large organ that lies ...
# 1181  ['', 'The shingles rash is associated with an ...
#
#                                            Risk factors  \
# 0     ['Acanthosis nigricans risk factors include:',...
# 2     ['Factors that may increase your risk of Achil...
# 3     ['The risk factors for acute coronary syndrome...
# 4     ['Risk factors for adenomyosis include:', 'Mos...
# 5     ['Some things may make you more likely to have...
# ...                                                 ...
# 1176  ['You may be at risk of the disease if you tra...
# 1177  ['The risk of developing plague is very low. W...
# 1179  ['Factors that put you at greater risk of deve...
# 1180  ["If you have a blood relative, such as a sibl...
# 1181  ['Anyone who has ever had chickenpox can devel...
#
#                                               diagnosis
# 0     ['Acanthosis nigricans is typically detected d...
# 2     ['During the physical exam, your doctor will i...
# 3     ['If you have signs or symptoms associated wit...
# 4     ['Some other uterine conditions can cause sign...
# 5     ['Diagnosis of adjustment disorders is based o...
# ...                                                 ...
# 1176  ['Diagnosing yellow fever based on signs and s...
# 1177  ['If your doctor suspects plague, he or she ma...
# 1179  ['The mosquito that carries the Zika virus is ...
# 1180  ['Your doctor will base a diagnosis on the fol...
# 1181  ['Shingles is usually diagnosed based on the h...
#
# [909 rows x 7 columns]

# %%
# Helper function to summarize large column to conform to Pinecone metadata upsert limits
# Initialize summarization pipeline
summary = pipeline('summarization')
def summarize_text(column_text):
  if len(column_text) > 10000:
    final_list = []
    chunks =  textwrap.wrap(column_text,1000)
    for chunk in chunks:
      final_list.append(summary(chunk)[0]['summary_text'])
    final_summary = " ".join(final_list)
    return final_summary
  else:
    return column_text
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
# Summarize large columns
df_ppNaN['Symptoms'] = df_ppNaN['Symptoms'].map(summarize_text)
df_ppNaN['Overview'] = df_ppNaN['Overview'].map(summarize_text)
df_ppNaN['Causes'] = df_ppNaN['Causes'].map(summarize_text)
df_ppNaN['Risk factors'] = df_ppNaN['Risk factors'].map(summarize_text)
df_ppNaN['diagnosis'] = df_ppNaN['diagnosis'].map(summarize_text)
# Out:
# Your max_length is set to 142, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Your max_length is set to 142, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)

# %%
df_ppNaN.head()
# Out:
#                       name                                               link  \
# 0     Acanthosis nigricans  https://www.mayoclinic.org/diseases-conditions...
# 2  Achilles tendon rupture  https://www.mayoclinic.org/diseases-conditions...
# 3  Acute coronary syndrome  https://www.mayoclinic.org/diseases-conditions...
# 4              Adenomyosis  https://www.mayoclinic.org/diseases-conditions...
# 5     Adjustment disorders  https://www.mayoclinic.org/diseases-conditions...
#
#                                             Symptoms  \
# 0  ["Skin changes are the only signs of acanthosi...
# 2  ["Although it's possible to have no signs or s...
# 3  ['The signs and symptoms of acute coronary syn...
# 4  ['Sometimes, adenomyosis causes no signs or sy...
# 5  ['Signs and symptoms depend on the type of adj...
#
#                                             Overview  \
# 0  ['', 'Acanthosis nigricans is a skin condition...
# 2  ['', 'The Achilles tendon is a strong fibrous ...
# 3  ['Acute coronary syndrome is a term used to de...
# 4  ['', 'With adenomyosis, the same tissue that l...
# 5  ['Adjustment disorders are stress-related cond...
#
#                                               Causes  \
# 0  ['Acanthosis nigricans has been associated wit...
# 2  ['Your Achilles tendon helps you point your fo...
# 3  ['Acute coronary syndrome usually results from...
# 4  ["The cause of adenomyosis isn't known. There ...
# 5  ['Adjustment disorders are caused by significa...
#
#                                         Risk factors  \
# 0  ['Acanthosis nigricans risk factors include:',...
# 2  ['Factors that may increase your risk of Achil...
# 3  ['The risk factors for acute coronary syndrome...
# 4  ['Risk factors for adenomyosis include:', 'Mos...
# 5  ['Some things may make you more likely to have...
#
#                                            diagnosis
# 0  ['Acanthosis nigricans is typically detected d...
# 2  ['During the physical exam, your doctor will i...
# 3  ['If you have signs or symptoms associated wit...
# 4  ['Some other uterine conditions can cause sign...
# 5  ['Diagnosis of adjustment disorders is based o...

# %%
# Batch for embedding and upsert into Pinecone  
embeddings = []
content = []
BATCH_SIZE = 32
for batch_start in range(0, len(df_ppNaN), BATCH_SIZE):
    batch_end = batch_start + BATCH_SIZE
    #get batch id
    batch_ids  = [str(batch_start) for batch_start in range(batch_start,batch_end)]
    symptoms_batch = df_ppNaN['Symptoms'].values.tolist()[batch_start:batch_end]
    link_batch = df_ppNaN['link'].values.tolist()[batch_start:batch_end]
    name_batch = df_ppNaN['name'].values.tolist()[batch_start:batch_end]
    overview_batch = df_ppNaN['Overview'].values.tolist()[batch_start:batch_end]
    causes_batch = df_ppNaN['Causes'].values.tolist()[batch_start:batch_end]
    risk_factors_batch = df_ppNaN['Risk factors'].values.tolist()[batch_start:batch_end]
    diagnosis_batch = df_ppNaN['diagnosis'].values.tolist()[batch_start:batch_end]
    batch_content = [{'symptoms':symptoms,'overview':overview,'causes':causes,'riskf':risk_factors,'diagnosis':diagnosis,'name':name,'source':link} for symptoms,overview,causes,risk_factors,diagnosis,name,link in zip(symptoms_batch,overview_batch,causes_batch,risk_factors_batch,diagnosis_batch,name_batch,link_batch)]
    print(f"Batch {batch_start} to {batch_end-1}")
    #response = client.embeddings.create(model=model, input=batch_text)
    response = openai.Embedding.create(input=text_batch,engine=model)
    for i, be in enumerate(response.data):
        assert i == be.index  # double check embeddings are in same order as input
    #batch_embeddings = [e.embedding for e in response.data]
    batch_embeddings = [ record['embedding'] for record in response['data']]  
    embeddings.extend(batch_embeddings)
    content.extend(batch_content)
    #upsert to pinecone
    to_upsert = zip(batch_ids,batch_embeddings,batch_content)
    index.upsert(vectors=list(to_upsert))
    
index.describe_index_stats()    
dfUpsert = pd.DataFrame({"content": content, "embedding": embeddings})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 content = []
#       4 BATCH_SIZE = 32
# ----> 5 for batch_start in range(0, len(df_ppNaN), BATCH_SIZE):
#       6     batch_end = batch_start + BATCH_SIZE
#       7     #get batch id
#
# NameError: name 'df_ppNaN' is not defined

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.00909,
#  'namespaces': {'': {'vector_count': 909}},
#  'total_vector_count': 909}

# %%
dfUpsert.head()
# Out:
#                                              content  \
# 0  {'symptoms': '["Skin changes are the only sign...
# 1  {'symptoms': '["Although it's possible to have...
# 2  {'symptoms': '['The signs and symptoms of acut...
# 3  {'symptoms': '['Sometimes, adenomyosis causes ...
# 4  {'symptoms': '['Signs and symptoms depend on t...
#
#                                            embedding
# 0  [0.0010588630102574825, -0.008330042473971844,...
# 1  [-0.0017860711086541414, -0.007644194643944502...
# 2  [-0.013818983919918537, -0.004287558142095804,...
# 3  [-0.02348223328590393, -0.026248667389154434, ...
# 4  [-0.01782934181392193, 0.006055957637727261, 0...
